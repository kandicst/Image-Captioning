# %% [markdown]
# ## Data preprocessing

# %%
import torch
import os
import json
from PIL import Image
import numpy as np

from layers.VGG19 import VGG19
from torch.utils.data import DataLoader
from torchvision import transforms
from MyDataset import MyDataset

# %%
coco_train_path = 'mscoco/train/annotations/captions_train2014.json'
coco_test_path = 'mscoco/test/annotations/captions_val2014.json'
extracted_data_path = 'extracted_data/'

extracted_imgs_train = 'extracted_data/train/vecs/'
extracted_imgs_test = 'extracted_data/test/vecs/'

train_size = 50000

# %%
def save_captions(in_file, out_file, im_type='train'):
    with open(in_file) as f:
        data = json.load(f)

    captions = []
    image_paths = []
    path = '/'.join(in_file.split('/')[:2]) + '/img/'

    for element in data['annotations']:
        captions.append('<START> ' + element['caption'] + ' <END>')
        image_id = element['image_id']
        image_paths.append(path + 'COCO_%s2014_%012d' % (im_type, image_id))

    with open(out_file + '/captions.json', 'w') as f1:
        f1.write(json.dumps(captions))

    with open(out_file + '/image_paths.json', 'w') as f2:
        f2.write(json.dumps(image_paths))

    return captions, image_paths

# %%
train_captions, train_image_paths = save_captions(coco_train_path, 
                                                  extracted_data_path + 'train')

# %%
test_captions, test_image_paths = save_captions(coco_test_path, 
                                                extracted_data_path + 'test', 'val')

# %% [markdown]
# ### Verify data

# %%
index = int(np.random.random() * 1000)
im = Image.open(train_image_paths[index]+'.jpg')
display(im)
print(train_captions[index])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x424 at 0x19D29B98588>
# <START> A woman with a cold drink is staring at a laptop. <END>

# %% [markdown]
# ## Cache image data

# %%
vgg = VGG19()

# %%
def preprocess_image(img_path):
    img = Image.open(img_path +'.jpg')
    if len(np.array(img).shape) == 2: 
        img = img.convert('RGB')
    img = transform_image(img)
    return img


def transform_image(img, input_size=224):
    img = transforms.Resize(input_size)(img)
    img = transforms.CenterCrop(input_size)(img)
    img = transforms.ToTensor()(img)
    img =  transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])(img)
    return img.unsqueeze(0)

# %%
def cache(img_paths, output_dir):
    for image_name in sorted(set(img_paths)):
        img = preprocess_image(image_name)
        img = vgg(img)
        torch.save(img, output_dir + image_name.split('/')[-1] + '.pt')

# %%
cache(train_image_paths, extracted_imgs_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-073c473eeeff> in <module>
# ----> 1 cache(train_image_paths, extracted_imgs_train)
#
# <ipython-input-12-82dfb5701c21> in cache(img_paths, output_dir)
#       2     for image_name in sorted(set(img_paths)):
#       3         img = preprocess_image(image_name)
# ----> 4         img = vgg(img)
#       5         torch.save(img, output_dir + image_name.split('/')[-1] + '.pt')
#
# c:\users\stefan\appdata\local\programs\python\python37\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~\Desktop\Treca Godina\ORI\Image Captioning\ORI_ML\layers\VGG19.py in forward(self, x)
#      18
#      19     def forward(self, x):
# ---> 20         return self.features(x)
#      21
#      22 if __name__ == '__main__':
#
# c:\users\stefan\appdata\local\programs\python\python37\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# c:\users\stefan\appdata\local\programs\python\python37\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#      98     def forward(self, input):
#      99         for module in self:
# --> 100             input = module(input)
#     101         return input
#     102
#
# c:\users\stefan\appdata\local\programs\python\python37\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# c:\users\stefan\appdata\local\programs\python\python37\lib\site-packages\torch\nn\modules\conv.py in forward(self, input)
#     351
#     352     def forward(self, input):
# --> 353         return self._conv_forward(input, self.weight)
#     354
#     355 class Conv3d(_ConvNd):
#
# c:\users\stefan\appdata\local\programs\python\python37\lib\site-packages\torch\nn\modules\conv.py in _conv_forward(self, input, weight)
#     348                             _pair(0), self.dilation, self.groups)
#     349         return F.conv2d(input, weight, self.bias, self.stride,
# --> 350                         self.padding, self.dilation, self.groups)
#     351
#     352     def forward(self, input):
#
# KeyboardInterrupt:
